# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
wine=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data')

# %%
wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine.drop(wine.iloc[:,[0,3,6,8,10,12,13]],axis=1,inplace=True)

# %%
wine
# Out:
#      14.23  1.71  15.6  127  3.06  2.29  1.04
# 0    13.20  1.78  11.2  100  2.76  1.28  1.05
# 1    13.16  2.36  18.6  101  3.24  2.81  1.03
# 2    14.37  1.95  16.8  113  3.49  2.18  0.86
# 3    13.24  2.59  21.0  118  2.69  1.82  1.04
# 4    14.20  1.76  15.2  112  3.39  1.97  1.05
# ..     ...   ...   ...  ...   ...   ...   ...
# 172  13.71  5.65  20.5   95  0.61  1.06  0.64
# 173  13.40  3.91  23.0  102  0.75  1.41  0.70
# 174  13.27  4.28  20.0  120  0.69  1.35  0.59
# 175  13.17  2.59  20.0  120  0.68  1.46  0.60
# 176  14.13  4.10  24.5   96  0.76  1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
col=['alcohol','malic_acid','alcalinity_of_ash','magnesium','flavanoids','proanthocyanins','hue']

# %%
wine.columns=col

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      13.20        1.78               11.2        100        2.76
# 1      13.16        2.36               18.6        101        3.24
# 2      14.37        1.95               16.8        113        3.49
# 3      13.24        2.59               21.0        118        2.69
# 4      14.20        1.76               15.2        112        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5         95        0.61
# 173    13.40        3.91               23.0        102        0.75
# 174    13.27        4.28               20.0        120        0.69
# 175    13.17        2.59               20.0        120        0.68
# 176    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# 4               1.97  1.05
# ..               ...   ...
# 172             1.06  0.64
# 173             1.41  0.70
# 174             1.35  0.59
# 175             1.46  0.60
# 176             1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.loc[:2,['alcohol']]=np.nan

# %%
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        100        2.76
# 1      NaN        2.36               18.6        101        3.24
# 2      NaN        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[3:4,['magnesium']]=np.nan

# %%
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8      113.0        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2        NaN        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.alcohol.fillna(10,inplace=True)

# %%
wine.magnesium.fillna(100,inplace=True)

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.76
# 1      10.00        2.36               18.6      101.0        3.24
# 2      10.00        1.95               16.8      113.0        3.49
# 3      13.24        2.59               21.0      100.0        2.69
# 4      14.20        1.76               15.2      100.0        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# 4               1.97  1.05
# ..               ...   ...
# 172             1.06  0.64
# 173             1.41  0.70
# 174             1.35  0.59
# 175             1.46  0.60
# 176             1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isna().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
arr=np.random.randint(0,10,10)

# %%
arr
# Out:
# array([2, 9, 5, 4, 9, 0, 6, 5, 0, 1])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.loc[arr]=np.nan

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN         NaN                NaN        NaN         NaN
# 1        NaN         NaN                NaN        NaN         NaN
# 2        NaN         NaN                NaN        NaN         NaN
# 3      13.24        2.59               21.0      100.0        2.69
# 4        NaN         NaN                NaN        NaN         NaN
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0                NaN   NaN
# 1                NaN   NaN
# 2                NaN   NaN
# 3               1.82  1.04
# 4                NaN   NaN
# ..               ...   ...
# 172             1.06  0.64
# 173             1.41  0.70
# 174             1.35  0.59
# 175             1.46  0.60
# 176             1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isna().sum()
# Out:
# alcohol              7
# malic_acid           7
# alcalinity_of_ash    7
# magnesium            7
# flavanoids           7
# proanthocyanins      7
# hue                  7
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine.dropna(inplace=True)
wine.head()
# Out:
#     alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 3     13.24        2.59               21.0      100.0        2.69
# 7     14.83        1.64               14.0       97.0        2.98
# 8     13.86        1.35               16.0       98.0        3.15
# 10    14.12        1.48               16.8       95.0        2.43
# 11    13.75        1.73               16.0       89.0        2.76
#
#     proanthocyanins   hue
# 3              1.82  1.04
# 7              1.98  1.08
# 8              1.85  1.01
# 10             1.57  1.17
# 11             1.81  1.15

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine.alcohol[wine.alcohol.notnull()]
# Out:
# 0      13.24
# 1      14.83
# 2      13.86
# 3      14.12
# 4      13.75
#        ...
# 165    13.71
# 166    13.40
# 167    13.27
# 168    13.17
# 169    14.13
# Name: alcohol, Length: 170, dtype: float64

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine.reset_index(drop=True,inplace=True)

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      13.24        2.59               21.0      100.0        2.69
# 1      14.83        1.64               14.0       97.0        2.98
# 2      13.86        1.35               16.0       98.0        3.15
# 3      14.12        1.48               16.8       95.0        2.43
# 4      13.75        1.73               16.0       89.0        2.76
# ..       ...         ...                ...        ...         ...
# 165    13.71        5.65               20.5       95.0        0.61
# 166    13.40        3.91               23.0      102.0        0.75
# 167    13.27        4.28               20.0      120.0        0.69
# 168    13.17        2.59               20.0      120.0        0.68
# 169    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.82  1.04
# 1               1.98  1.08
# 2               1.85  1.01
# 3               1.57  1.17
# 4               1.81  1.15
# ..               ...   ...
# 165             1.06  0.64
# 166             1.41  0.70
# 167             1.35  0.59
# 168             1.46  0.60
# 169             1.35  0.61
#
# [170 rows x 7 columns]

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# ### Fill 150 to 160 rows of flavanoids column as NAN

# %%
wine.loc[150:160,['flavanoids']]=np.NAN

# %%
wine.loc[150:160]
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 150    14.34        1.68               25.0       98.0         NaN
# 151    13.48        1.67               22.5       89.0         NaN
# 152    12.36        3.83               21.0       88.0         NaN
# 153    13.69        3.26               20.0      107.0         NaN
# 154    12.85        3.27               22.0      106.0         NaN
# 155    12.96        3.45               18.5      106.0         NaN
# 156    13.78        2.76               22.0       90.0         NaN
# 157    13.73        4.36               22.5       88.0         NaN
# 158    13.45        3.70               23.0      111.0         NaN
# 159    12.82        3.37               19.5       88.0         NaN
# 160    13.58        2.58               24.5      105.0         NaN
#
#      proanthocyanins   hue
# 150             2.70  0.57
# 151             2.29  0.57
# 152             1.04  0.56
# 153             0.80  0.96
# 154             0.96  0.87
# 155             0.94  0.68
# 156             1.03  0.70
# 157             1.15  0.78
# 158             1.46  0.85
# 159             0.97  0.72
# 160             1.54  0.74
