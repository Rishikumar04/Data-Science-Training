# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo=pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.item_price=chipo.item_price.str.replace('$','').astype(float)

# %%
chipo[(chipo['item_price']>10.00) & (chipo['quantity']==1)].drop_duplicates('item_name')
# Out:
#       order_id  quantity              item_name  \
# 5            3         1           Chicken Bowl
# 7            4         1          Steak Burrito
# 23          12         1        Chicken Burrito
# 39          19         1          Barbacoa Bowl
# 57          26         1         Veggie Burrito
# 62          28         1            Veggie Bowl
# 79          35         1     Chicken Soft Tacos
# 90          40         1             Steak Bowl
# 93          41         1       Carnitas Burrito
# 97          43         1          Carnitas Bowl
# 130         57         1       Barbacoa Burrito
# 168         75         1  Barbacoa Crispy Tacos
# 186         83         1      Veggie Salad Bowl
# 250        109         1          Chicken Salad
# 365        158         1   Chicken Crispy Tacos
# 606        250         1       Steak Salad Bowl
# 738        304         1      Veggie Soft Tacos
# 988        406         1    Barbacoa Soft Tacos
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo.drop_duplicates('item_name').loc[chipo['quantity']==1].sort_values('item_price',ascending=False).loc[:,['item_name','item_price']]
# Out:
#                                   item_name  item_price
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 39                            Barbacoa Bowl       11.75
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 186                       Veggie Salad Bowl       11.25
# 738                       Veggie Soft Tacos       11.25
# 57                           Veggie Burrito       11.25
# 62                              Veggie Bowl       11.25
# 250                           Chicken Salad       10.98
# 56                      Barbacoa Soft Tacos        9.25
# 92                       Steak Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 54                               Steak Bowl        8.99
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values('item_name').reset_index(drop=True)
# Out:
#       order_id  quantity          item_name  \
# 0         1360         2  6 Pack Soft Drink
# 1          148         1  6 Pack Soft Drink
# 2          749         1  6 Pack Soft Drink
# 3          754         1  6 Pack Soft Drink
# 4         1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 4617       948         1  Veggie Soft Tacos
# 4618       322         1  Veggie Soft Tacos
# 4619      1132         1  Veggie Soft Tacos
# 4620       688         1  Veggie Soft Tacos
# 4621       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 0                                           [Diet Coke]       12.98
# 1                                           [Diet Coke]        6.49
# 2                                                [Coke]        6.49
# 3                                           [Diet Coke]        6.49
# 4                                                [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values('item_price',ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo.item_name.value_counts().loc['Veggie Salad Bowl']
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo['item_name']=='Canned Soda') & (chipo['quantity']>1)].count()[0]
# Out:
# 20
